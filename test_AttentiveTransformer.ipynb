# %%
import tensorflow as tf
from LorisBallsBasedModel import *

# %%
X = tf.ones(shape=(1000, 1))
y = 2*X+1

d = tf.data.Dataset.from_tensor_slices((X,
                                        y)).batch(10)

# %%
class SingleLayerPerceptron(tf.keras.Model):
    def __init__(self,
                 output_layer,
                 **kwargs):
        super().__init__(**kwargs)
        self.output_layer = output_layer
        
    def call(self, inputs):
        r = self.output_layer(inputs)
        return r

# %%
model = SingleLayerPerceptron(tf.keras.layers.Dense(1, activity_regularizer=tf.keras.regularizers.L2(0.)))
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['acc'])
model.fit(d, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 1s 1ms/step - loss: 10.0505 - acc: 0.0000e+00
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 8.8522 - acc: 0.0000e+00
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 7.7639 - acc: 0.0000e+00
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 6.7790 - acc: 0.0000e+00
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 5.8907 - acc: 0.0000e+00
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 5.0927 - acc: 0.0000e+00
# Epoch 7/50
# 100/100 [==============================] - 0s 959us/step - loss: 4.3788 - acc: 0.0000e+00
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 3.7429 - acc: 0.0000e+00
# Epoch 9/50
# 100/100 [==============================] - 0s 1ms/step - loss: 3.1794 - acc: 0.0000e+00
# Epoch 10/50
# ...

# %%
model = SingleLayerPerceptron(tf.keras.layers.Dense(1, activity_regularizer=tf.keras.regularizers.L2(10.)))
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['acc'])
model.fit(d, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 13.7909 - acc: 0.0000e+00
# Epoch 2/50
# 100/100 [==============================] - 0s 2ms/step - loss: 11.3412 - acc: 0.0000e+00
# Epoch 3/50
# 100/100 [==============================] - 0s 868us/step - loss: 9.8211 - acc: 0.0000e+00
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 8.9567 - acc: 0.0000e+00
# Epoch 5/50
# 100/100 [==============================] - 0s 1ms/step - loss: 8.5121 - acc: 0.0000e+00
# Epoch 6/50
# 100/100 [==============================] - 0s 942us/step - loss: 8.3077 - acc: 0.0000e+00
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 8.2244 - acc: 0.0000e+00
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 8.1946 - acc: 0.0000e+00
# Epoch 9/50
# 100/100 [==============================] - 0s 963us/step - loss: 8.1852 - acc: 0.0000e+00
# Epoch 10/50
# ...

# %%
class SingleLayerPerceptron(tf.keras.Model):
    def __init__(self,
                 output_layer,
                 **kwargs):
        super().__init__(**kwargs)
        self.output_layer = output_layer
        
    def call(self, inputs):
        r = self.output_layer(inputs)
        self.add_loss(tf.keras.regularizers.L2(0.)(r))
        return r

# %%
model = SingleLayerPerceptron(tf.keras.layers.Dense(1))
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['acc'])
model.fit(X, y, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 1ms/step - loss: 11.1320 - acc: 0.0000e+00
# Epoch 2/50
# 100/100 [==============================] - 0s 1ms/step - loss: 9.8672 - acc: 0.0000e+00
# Epoch 3/50
# 100/100 [==============================] - 0s 1ms/step - loss: 8.7129 - acc: 0.0000e+00
# Epoch 4/50
# 100/100 [==============================] - 0s 1ms/step - loss: 7.6627 - acc: 0.0000e+00
# Epoch 5/50
# 100/100 [==============================] - 0s 903us/step - loss: 6.7101 - acc: 0.0000e+00
# Epoch 6/50
# 100/100 [==============================] - 0s 1ms/step - loss: 5.8489 - acc: 0.0000e+00
# Epoch 7/50
# 100/100 [==============================] - 0s 1ms/step - loss: 5.0733 - acc: 0.0000e+00
# Epoch 8/50
# 100/100 [==============================] - 0s 1ms/step - loss: 4.3775 - acc: 0.0000e+00
# Epoch 9/50
# 100/100 [==============================] - 0s 985us/step - loss: 3.7560 - acc: 0.0000e+00
# Epoch 10/50
# ...

# %%
class SingleLayerPerceptron(tf.keras.Model):
    def __init__(self,
                 output_layer,
                 **kwargs):
        super().__init__(**kwargs)
        self.output_layer = output_layer
        
    def call(self, inputs):
        r = self.output_layer(inputs)
        self.add_loss(tf.keras.regularizers.get(tf.keras.regularizers.L2(10.))(r))
        return r

# %%
model = SingleLayerPerceptron(tf.keras.layers.Dense(1))
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['acc'])
model.fit(X, y, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 1ms/step - loss: 704.3364 - acc: 0.0000e+00
# Epoch 2/50
# 32/32 [==============================] - 0s 1ms/step - loss: 646.6374 - acc: 0.0000e+00
# Epoch 3/50
# 32/32 [==============================] - 0s 1ms/step - loss: 592.5487 - acc: 0.0000e+00
# Epoch 4/50
# 32/32 [==============================] - 0s 1ms/step - loss: 541.9263 - acc: 0.0000e+00
# Epoch 5/50
# 32/32 [==============================] - 0s 1ms/step - loss: 494.6708 - acc: 0.0000e+00
# Epoch 6/50
# 32/32 [==============================] - 0s 1ms/step - loss: 450.6536 - acc: 0.0000e+00
# Epoch 7/50
# 32/32 [==============================] - 0s 981us/step - loss: 409.7387 - acc: 0.0000e+00
# Epoch 8/50
# 32/32 [==============================] - 0s 1ms/step - loss: 371.7878 - acc: 0.0000e+00
# Epoch 9/50
# 32/32 [==============================] - 0s 1ms/step - loss: 336.6621 - acc: 0.0000e+00
# Epoch 10/50
# ...

# %%
mask = tf.random.uniform([32, 5])
epsilon = 1e-8


tf.reduce_mean(
    tf.reduce_sum(-mask * tf.math.log(mask + epsilon), axis=-1)
)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.2323496>
